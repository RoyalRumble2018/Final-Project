# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Importing libraries.

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import calendar
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib.pylab import rcParams
import seaborn as sns

# %% [markdown]
# Importing csv file.

# %%
df = pd.read_csv('liver_disease.csv')

# %%
df.shape
# Out:
# (378, 12)

# %% [markdown]
# Let's find out the null values in our dataset.

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             4
# is_patient          0
# dtype: int64

# %% [markdown]
# Let's find out the type of data in our dataset.

# %%
df.dtypes
# Out:
# id                    int64
# age                   int64
# gender               object
# tot_bilirubin       float64
# direct_bilirubin    float64
# tot_proteins          int64
# albumin               int64
# ag_ratio              int64
# sgpt                float64
# sgot                float64
# alkphos             float64
# is_patient            int64
# dtype: object

# %% [markdown]
# Now let's find out who are patient or not with respect to age.

# %%
plt.rcParams['figure.figsize'] = (30, 8)
d = df.groupby(['age', 'is_patient']).size().unstack(level=1)
d = d / d.mean()
p = d.plot(kind='bar')

# %% [markdown]
# In our dataset, data is distributed evenly over all ages. Highest number of patients are recorder at age 38 and 65. Highest age of not patient is at age = 60.

# %% [markdown]
# Let's find out how patients are divided over gender.

# %%
plt.rcParams['figure.figsize'] = (8, 8)
d = df.groupby(['gender', 'is_patient']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# In our dataset, number of female with disease are more as compared to completely well female. Number of male with disease is less than those who are well.

# %% [markdown]
# Finding co-relation between columns.

# %%
corr_df = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_df, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Correlations between different predictors')
plt.show()

# %% [markdown]
# From the heat map, we can understand that ‘age’ have less coorealtion with every column. ‘ag_ratio’ and ‘albumin’ have higher correlation between ‘tot_bilirubin’ and ‘direct_bilirubin’. ‘alkphos’ have higher correlation with ‘sgpt’ and ‘sgot’.

# %%
is_patient = pd.DataFrame(df.groupby('is_patient').size()).idxmax()[0]
df['is_patient'] = df['is_patient'].fillna(is_patient)
sns.countplot(data=df,x='is_patient')

# %%
df['is_patient'].value_counts()
# Out:
# 1    211
# 2    167
# Name: is_patient, dtype: int64

# %% [markdown]
# There are 211 entries of people without liver disease and 167 entrie of people with liver disease.

# %% [markdown]
# EDA is also continued in Tableau. Link for them are mentioned below.

# %% [markdown]
# https://public.tableau.com/profile/nitin.prince.reuben#!/vizhome/EDA_liver/Dashboard1?publish=yes

# %% [markdown]
# Short form and full form of certain columns.

# %% [markdown]
# ![liver.PNG](attachment:liver.PNG)
